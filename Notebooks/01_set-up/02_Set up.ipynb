# %% [markdown]
# Creating External Location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS bronze_ext_location
URL 'abfss://projectstorage@eprojectstorageacc.dfs.core.windows.net/bronze'
WITH (STORAGE CREDENTIAL bronze_cred);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS silver_ext_location
URL 'abfss://projectstorage@eprojectstorageacc.dfs.core.windows.net/silver'
WITH (STORAGE CREDENTIAL bronze_cred);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS gold_ext_location
URL 'abfss://projectstorage@eprojectstorageacc.dfs.core.windows.net/gold'
WITH (STORAGE CREDENTIAL bronze_cred);

# %% [markdown]
# Creating Catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS ecommerce;
USE CATALOG ecommerce;

# %% [markdown]
# Creating Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce.bronze
managed LOCATION 'abfss://projectstorage@eprojectstorageacc.dfs.core.windows.net/bronze';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce.silver
managed LOCATION 'abfss://projectstorage@eprojectstorageacc.dfs.core.windows.net/silver';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce.gold
managed LOCATION 'abfss://projectstorage@eprojectstorageacc.dfs.core.windows.net/gold';
